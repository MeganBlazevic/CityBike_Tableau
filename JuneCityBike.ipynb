# %% [markdown]
# ## City Bike Data
# ### June data for 2018, 2019, and 2020

# %%
# Dependencies
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Load in CSV files and save dataframes
june2018 = pd.read_csv("monthly_data/201806-citibike-tripdata.csv")
june2019 = pd.read_csv("monthly_data/201906-citibike-tripdata.csv")
june2020 = pd.read_csv("monthly_data/202006-citibike-tripdata.csv")

# %%
# Combine 2018, 2019, 2020 as they have similar column names
june181920 = june2018.append([june2019, june2020], ignore_index = True)
june181920.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1           480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2           692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3           664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4           818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  \
# 0               -73.993929             173  Broadway & W 49 St
# 1               -73.993929             477     W 41 St & 8 Ave
# 2               -73.993929             457  Broadway & W 58 St
# 3               -73.993929             379     W 31 St & 7 Ave
# 4               -73.993929             459    W 20 St & 11 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.760683             -73.984527   21481  Subscriber
# 1             40.756405             -73.990026   19123  Subscriber
# 2             40.766953             -73.981693   26983  Subscriber
# 3             40.749156             -73.991600   26742  Subscriber
# 4             40.746745             -74.007756   26386  Subscriber
#
#    birth year  gender
# 0        1999       1
# 1        1988       1
# 2        1986       1
# 3        1973       1
# 4        1984       1

# %%
# Rename column names to match the eventual ending data set
june181920 = june181920.rename(columns={"starttime": "Start Time", 
                                    "stoptime": "Stop Time",
                                    "start station id": "Start Station ID",
                                    "start station name": "Start Sation Name",
                                    "start station latitude": "Start Station Lat",
                                    "start station longitude": "Start Station Lng",
                                    "end station id": "End Station ID",
                                    "end station name": "End Station Name",
                                    "end station latitude": "End Station Lat",
                                    "end station longitude": "End Station Lng",
                                    "usertype": "Member Type",
                                    "gender": "Gender",
                                    })

# %%
# Drop incomplete trips
june181920.dropna
# Out:
# <bound method DataFrame.dropna of          tripduration                Start Time                 Stop Time  \
# 0                 569  2018-06-01 01:57:20.5140  2018-06-01 02:06:50.0880
# 1                 480  2018-06-01 02:02:42.3980  2018-06-01 02:10:43.3540
# 2                 692  2018-06-01 02:04:23.6240  2018-06-01 02:15:55.7470
# 3                 664  2018-06-01 03:00:55.4610  2018-06-01 03:11:59.9060
# 4                 818  2018-06-01 06:04:54.4270  2018-06-01 06:18:32.6170
# ...               ...                       ...                       ...
# 5960741           685  2020-06-30 23:59:41.1160  2020-07-01 00:11:06.7790
# 5960742           446  2020-06-30 23:59:46.4260  2020-07-01 00:07:13.0860
# 5960743           439  2020-06-30 23:59:47.4770  2020-07-01 00:07:06.5590
# 5960744           890  2020-06-30 23:59:53.3950  2020-07-01 00:14:43.4270
# 5960745           433  2020-06-30 23:59:53.9010  2020-07-01 00:07:07.0950
#
#          Start Station ID          Start Sation Name  Start Station Lat  \
# 0                      72           W 52 St & 11 Ave          40.767272
# 1                      72           W 52 St & 11 Ave          40.767272
# 2                      72           W 52 St & 11 Ave          40.767272
# 3                      72           W 52 St & 11 Ave          40.767272
# 4                      72           W 52 St & 11 Ave          40.767272
# ...                   ...                        ...                ...
# 5960741               503         E 20 St & Park Ave          40.738274
# 5960742              3699            W 50 St & 9 Ave          40.763605
# 5960743              3699            W 50 St & 9 Ave          40.763605
# 5960744              3852  Stewart Ave & Johnson Ave          40.708690
# 5960745               324    DeKalb Ave & Hudson Ave          40.689888
#
#          Start Station Lng  End Station ID         End Station Name  \
# 0               -73.993929             173       Broadway & W 49 St
# 1               -73.993929             477          W 41 St & 8 Ave
# 2               -73.993929             457       Broadway & W 58 St
# 3               -73.993929             379          W 31 St & 7 Ave
# 4               -73.993929             459         W 20 St & 11 Ave
# ...                    ...             ...                      ...
# 5960741         -73.987520            3746        6 Ave & Broome St
# 5960742         -73.989180             523          W 38 St & 8 Ave
# 5960743         -73.989180             523          W 38 St & 8 Ave
# 5960744         -73.925870            3054  Greene Ave & Throop Ave
# 5960745         -73.981013             261     Johnson St & Gold St
#
#          End Station Lat  End Station Lng  bikeid Member Type  birth year  \
# 0              40.760683       -73.984527   21481  Subscriber        1999
# 1              40.756405       -73.990026   19123  Subscriber        1988
# 2              40.766953       -73.981693   26983  Subscriber        1986
# 3              40.749156       -73.991600   26742  Subscriber        1973
# 4              40.746745       -74.007756   26386  Subscriber        1984
# ...                  ...              ...     ...         ...         ...
# 5960741        40.724308       -74.004730   21056    Customer        1993
# 5960742        40.754666       -73.991382   30164    Customer        1969
# 5960743        40.754666       -73.991382   43742    Customer        1986
# 5960744        40.689493       -73.942061   15787  Subscriber        1994
# 5960745        40.694749       -73.983625   38767    Customer        1990
#
#          Gender
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 5960741       2
# 5960742       0
# 5960743       1
# 5960744       1
# 5960745       1
#
# [5960746 rows x 15 columns]>

# %%
# Convert the data and time to the same time format.
june181920["Start Time"] = pd.to_datetime(june181920["Start Time"])
june181920["Stop Time"] = pd.to_datetime(june181920["Stop Time"])

# %%
# Change the Gender column from values to names
june181920["Gender"].replace([0,1,2], ["unknown", "male", "female"], inplace=True)

# %%
june181920.dtypes
# Out:
# tripduration                  int64
# Start Time           datetime64[ns]
# Stop Time            datetime64[ns]
# Start Station ID              int64
# Start Sation Name            object
# Start Station Lat           float64
# Start Station Lng           float64
# End Station ID                int64
# End Station Name             object
# End Station Lat             float64
# End Station Lng             float64
# bikeid                        int64
# Member Type                  object
# birth year                    int64
# Gender                       object
# dtype: object

# %%
# Confirm the data set
june181920.head()
# Out:
#    tripduration              Start Time               Stop Time  \
# 0           569 2018-06-01 01:57:20.514 2018-06-01 02:06:50.088
# 1           480 2018-06-01 02:02:42.398 2018-06-01 02:10:43.354
# 2           692 2018-06-01 02:04:23.624 2018-06-01 02:15:55.747
# 3           664 2018-06-01 03:00:55.461 2018-06-01 03:11:59.906
# 4           818 2018-06-01 06:04:54.427 2018-06-01 06:18:32.617
#
#    Start Station ID Start Sation Name  Start Station Lat  Start Station Lng  \
# 0                72  W 52 St & 11 Ave          40.767272         -73.993929
# 1                72  W 52 St & 11 Ave          40.767272         -73.993929
# 2                72  W 52 St & 11 Ave          40.767272         -73.993929
# 3                72  W 52 St & 11 Ave          40.767272         -73.993929
# 4                72  W 52 St & 11 Ave          40.767272         -73.993929
#
#    End Station ID    End Station Name  End Station Lat  End Station Lng  \
# 0             173  Broadway & W 49 St        40.760683       -73.984527
# 1             477     W 41 St & 8 Ave        40.756405       -73.990026
# 2             457  Broadway & W 58 St        40.766953       -73.981693
# 3             379     W 31 St & 7 Ave        40.749156       -73.991600
# 4             459    W 20 St & 11 Ave        40.746745       -74.007756
#
#    bikeid Member Type  birth year Gender
# 0   21481  Subscriber        1999   male
# 1   19123  Subscriber        1988   male
# 2   26983  Subscriber        1986   male
# 3   26742  Subscriber        1973   male
# 4   26386  Subscriber        1984   male

# %%
# export combined dataframe to a new csv
june181920.to_csv("june18-20.csv", index = False)
